# %%
# Import statements
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
# load datasets
google = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\GOOGL_data.csv')
facebook = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\FB_data.csv')
apple = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\AAPL_data.csv')
amazon = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\AMZN_data.csv')
microsoft = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\MSFT_data.csv')

# %%
# Create figure
plt.figure(figsize=(16, 8), dpi=300)
# Plot data
plt.plot('date', 'close', data=google, label='Google')
plt.plot('date', 'close', data=facebook, label='Facebook')
plt.plot('date', 'close', data=apple, label='Apple')
plt.plot('date', 'close', data=amazon, label='Amazon')
plt.plot('date', 'close', data=microsoft, label='Microsoft')
# Specify ticks for x- and y-axis
plt.xticks(np.arange(0, 1260, 40), rotation=70)
plt.yticks(np.arange(0, 1450, 100))
# Add title and label for y-axis
plt.title('Stock trend', fontsize=16)
plt.ylabel('Closing price in $', fontsize=14)
# Add grid
plt.grid()
# Add legend
plt.legend()
# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'category': ['A', 'B', 'A', 'C', 'B'], 'value': [10, 15, 8, 12, 20]}
df = pd.DataFrame(data)
df.plot.bar(x='category', y='value')
plt.title('Value Distribution by Category')
plt.show()

# %%
import matplotlib.pyplot as plt

x_values = [2, 4, 6, 8]
y_values = [4, 6, 8, 10]

# Create the line plot with desired customizations
plt.plot(x_values, y_values, color='blue', marker='o', linestyle='dashed', linewidth=2, markersize=12)

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Line Plot Title')

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {'x':[2, 4, 6, 8],'y':[5, 7, 3, 9]}

df=pd.DataFrame(data)

# Create the line plot
plt.plot(x,y)

# Customize x-axis tick labels (replace weekdays with your desired labels)
plt.xticks([2, 4, 6, 8], ['Monday', 'Tuesday', 'Wednesday', 'Thursday'],rotation=90)

# Rotate y-axis tick labels for better readability
plt.yticks(rotation=90)  # You can adjust the rotation angle as needed

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Line Plot Title')

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
data = {'x': [2, 4, 6, 8], 'y': [5, 7, 3, 9]}
df = pd.DataFrame(data)

# Plotting
plt.plot(df['x'], df['y'])  # Access x and y from the DataFrame

# Customizing x-ticks and y-ticks
plt.xticks([2, 4, 6, 8], ['Monday', 'Tuesday', 'Wednesday', 'Thursday'], rotation=90)
plt.yticks(rotation=90)

# Adding labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Line Plot Title')

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np  # Add this line to import numpy

plt.figure(figsize=(6, 3))
plt.plot([2, 4, 6, 8], 'o', [1, 5, 9, 13], 's')
plt.xticks(ticks=np.arange(4), labels=['January', 'February', 'March','April'], rotation=20)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[5,7,4])

plt.show()

# %%
x=[1,2,3]
y=[5,7,4]
x1=[1,2,3]
y1=[10,14,12]
x2=[1,4,8]
y2=[12,4,14]
x3=[1,2,3,4]
y3=[1,2,1,6]

plt.plot(x,y,label='1st line',color='red',linestyle='dashed',linewidth='2')
plt.plot(x1,y1,label='2nd line',color='green',linestyle='dotted',linewidth='4')
plt.plot(x2,y2,label='3rd line',color='orange',linestyle='solid',linewidth='2')
plt.plot(x3,y3,label='4th line',color='purple',linestyle='dashdot',linewidth='1')

plt.xlabel('Plot number')
plt.ylabel('Important var')

plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'x': [2, 4, 6, 8], 'y': [5, 7, 3, 9]}
df = pd.DataFrame(data)
a = df['x']
b = df['y']
plt.plot(a, b)
plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.xticks([2, 4, 6, 8], ['Monday', 'Tuesday', 'Wednesday', 'Thursday'], rotation=90,color="red")
plt.title('Line Plot Title')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'category': ['A', 'B', 'A', 'C', 'B'], 'value': [10, 15, 8, 12, 20]}
df = pd.DataFrame(data)
df.plot.bar(x='category', y='value')
plt.title('Value Distribution by Category')
plt.show()

# %%
    import pandas as pd
    import matplotlib.pyplot as plt

# %%
            data = {'x': [2, 4, 6, 8], 'y': [5, 7, 3, 9]}
            df = pd.DataFrame(data)
            a = df['x']
            b = df['y']

# %%
# Import statements
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
# load datasets
google = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\GOOGL_data.csv')
facebook = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\FB_data.csv')
apple = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\AAPL_data.csv')
amazon = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\AMZN_data.csv')
microsoft = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\MSFT_data.csv')

# %%
# Create figure
plt.figure(figsize=(16, 8), dpi=300)
# Plot data
plt.plot('date', 'close', data=google, label='Google')
plt.plot('date', 'close', data=facebook, label='Facebook')
plt.plot('date', 'close', data=apple, label='Apple')
plt.plot('date', 'close', data=amazon, label='Amazon')
plt.plot('date', 'close', data=microsoft, label='Microsoft')
# Specify ticks for x- and y-axis
plt.xticks(np.arange(0, 1260, 40), rotation=70)
plt.yticks(np.arange(0, 1450, 100))
# Add title and label for y-axis
plt.title('Stock trend', fontsize=16)
plt.ylabel('Closing price in $', fontsize=14)
# Add grid
plt.grid()
# Add legend
plt.legend()
# Show plot
plt.show()

# %%
                                                                                # Import statements
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

                                                                                 # load datasets
google = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\GOOGL_data.csv')
facebook = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\FB_data.csv')
apple = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\AAPL_data.csv')
amazon = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\AMZN_data.csv')
microsoft = pd.read_csv('C:\\Users\\USER\\Desktop\\Pandas code\\MSFT_data.csv')

                                                                                # Create figure
plt.figure(figsize=(16, 8), dpi=300)
                                                                                # Plot data
plt.plot('date', 'close', data=google, label='Google')
plt.plot('date', 'close', data=facebook, label='Facebook')
plt.plot('date', 'close', data=apple, label='Apple')
plt.plot('date', 'close', data=amazon, label='Amazon')
plt.plot('date', 'close', data=microsoft, label='Microsoft')
                                                                                # Specify ticks for x- and y-axis
plt.xticks(np.arange(0, 1260, 40), rotation=70)
plt.yticks(np.arange(0, 1450, 100))
                                                                                # Add title and label for y-axis
plt.title('Stock trend', fontsize=16)
plt.ylabel('Closing price in $', fontsize=14)
                                                                                # Add grid
plt.grid()
                                                                                # Add legend
plt.legend()
                                                                                # Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
            data = {'x': [2, 4, 6, 8], 'y': [5, 7, 3, 9]}
            df = pd.DataFrame(data)
            a = df['x']
            b = df['y']

# %%
plt.plot(a, b)
plt.plot([2, 4, 6, 8], color='red', linestyle='dashed', linewidth=2)
plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.xticks([2, 4, 6, 8], ['Monday', 'Tuesday', 'Wednesday', 'Thursday'],rotation=90)
plt.title('Line Plot Title')
plt.show( )

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {'category': ['A', 'B', 'A', 'C', 'B'], 'value': [10, 15, 8, 12, 20]}
df = pd.DataFrame(data)
df.plot.bar(x='category', y='value',color="red")
plt.title('Value Distribution by Category')
plt.show()
